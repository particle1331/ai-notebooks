# %% [markdown]
# # Deep Learning Foundations

# %% [markdown]
# **Deep learning systems** solved problems that were considered hard prior to 2010, e.g. obtaining superhuman / SOTA scores on tasks and challenges such as [ImageNet](https://www.image-net.org/challenges/LSVRC/), [CASP](https://en.wikipedia.org/wiki/CASP), and [Go (board game)](https://en.wikipedia.org/wiki/Computer_Go)[^1]. Later, in the early 2020s, unprecedented progress in text & image generation were made with models like GPT-3 and Stable Diffusion:
#
#
# [^1]: Game tree complexity of $10^{360}$ at 250 moves over 150 move games.

# %% [markdown]
# ![](./img/01-1.png){width=100%}

# %% [markdown]
# <br>

# %% [markdown]
# ## About This Series
#
# This series builds the mathematical and computational foundations of deep learning from scratch — in pure Python and PyTorch, deriving everything from first principles.
#
# **Audience:** Someone comfortable with Python, NumPy, and basic calculus who wants to understand how neural networks actually work before moving on to language models. A mathematics background is assumed — derivations are shown in full, not waved away. Code is the other half of the explanation.
#
# Every concept is grounded in code you write yourself. The core series ([01](01-softmax-regression.ipynb)-[05](05-activations-and-gradients.ipynb)) covers the full story from a single linear classifier through multi-layer networks, then builds up to automatic differentiation, modern gradient-based optimizers, and normalization layers. This provides a minimal prerequisite foundation for the [Language Models from Scratch](../llm/index.ipynb) series.

# %% [markdown]
# ## Course Contents
#
# ### Core Notebooks
#
# | # | Title | Topic |
# |---|---|---|
# | 01 | [Softmax Regression](01-softmax-regression.ipynb) | Softmax classifier, cross-entropy loss, gradient descent |
# | 02 | [Neural Networks](02-neural-networks.ipynb) | Multi-layer perceptrons, backpropagation, activations |
# | 03 | [Automatic Differentiation](03-autodiff.ipynb) | Computational graphs, reverse-mode AD, PyTorch autograd |
# | 04 | [Optimizers: SGD to AdamW](04-optimizers.ipynb) | GD, Momentum, RMSProp, Adam, AdamW, LR scheduling |
# | 05 | [Activations and Gradients](05-activations-and-gradients.ipynb) | Vanishing/exploding gradients, BatchNorm, initialization |
# | 06 | [Convolutional Networks](06-cnn.ipynb) | Convolutions, pooling, ResNets, image classification |
# | 07 | [Language Modeling](07-language-modeling.ipynb) | *N*-gram LMs, temporal convolutions, WaveNet |
# | 08 | [Recurrent Neural Networks](08-rnn.ipynb) | RNNs, LSTMs, GRUs, sequence-to-sequence |
# | 09 | [Attention & Transformers](09-attention-transformers.ipynb) | Self-attention, multi-head attention, Transformer encoder |
#
# : {tbl-colwidths="[6,36,58]"}
#
# ### Datasets
#
# | Dataset | Task | Used In |
# |---------|------|---------|
# | [MNIST](http://yann.lecun.com/exdb/mnist/) | Handwritten digit classification | 01, 06 |
# | [Spanish given names](https://github.com/jvalhondo/spanish-names-surnames) | Character-level language modeling, name gender classification | 05, 06, 07, 08 |
# | [Histopathologic Cancer Detection](https://www.kaggle.com/competitions/histopathologic-cancer-detection) | Transfer learning / fine-tuning | 06 |
# | [The Time Machine](http://www.gutenberg.org/ebooks/35) by H. G. Wells | Character-level language modeling | 07, 08 |
#
# : {tbl-colwidths="[30,55,15]"}
#
# ### Appendices
#
# | # | Title | Topic |
# |---|---|---|
# | 11 | [Appendix: Activation Patterns](11-appendix-expressivity.ipynb) | Universal approximation, depth vs width |
# | 12 | [Appendix: ResNet from Scratch](12-appendix-resnet.ipynb) | VGG baseline, residual blocks, build ResNet-18 on CIFAR-10 |
#
# : {tbl-colwidths="[6,36,58]"}

# %% [markdown]
# ## Advanced Topics
#
# Six notebooks applying the foundations to real tasks and architectures — machine translation, generative models, diffusion, segmentation, and image captioning. Each uses a small publicly available dataset and is designed to run on a single GPU, with CPU-accessible paths provided where training is expensive.
#
# | # | Title | Topic |
# |---|---|---|
# | 13 | [Machine Translation](13-translation.ipynb) | Encoder-decoder Transformer, cross-attention, Multi30k, BLEU |
# | 14 | [Generative Models](14-generative-models.ipynb) | VAE (ELBO, reparameterization trick), DCGAN, latent space |
# | 15 | [Diffusion Models](15-diffusion.ipynb) | DDPM, noise schedules, U-Net denoiser, MNIST/CIFAR-10 |
# | 16 | [Semantic Segmentation](16-segmentation.ipynb) | U-Net + ResNet encoder, Dice loss, Oxford-IIIT Pets |
# | 17 | [Image Captioning](17-captioning.ipynb) | ViT encoder + Transformer decoder, cross-modal attention, Flickr8k |
#
# : {tbl-colwidths="[6,30,64]"}

# %% [markdown]
# ## What You'll Build Understanding Of
#
# By the end of this series, you will understand:
#
# - How softmax regression and cross-entropy loss work from first principles, including gradient derivations
# - How multi-layer perceptrons and backpropagation work, with every matrix dimension accounted for
# - How computational graphs enable automatic differentiation, and how PyTorch's autograd engine implements reverse-mode AD
# - How gradient-based optimizers work — from vanilla gradient descent through Momentum, RMSProp, Adam, and AdamW — and how to tune learning rate schedules and batch size
# - How activation functions, batch normalization, and weight initialization affect gradient flow during training
# - How convolutional networks exploit spatial structure, and how residual connections enable very deep networks
# - How language models work — from n-grams through temporal convolutions to recurrent networks with gates
# - How attention mechanisms and Transformers replace recurrence with direct sequence modeling
#
# ## Prerequisites
#
# - Python 3.10+, PyTorch 2.0+, NumPy, Matplotlib
# - Linear algebra (matrix products, eigenvalues), calculus (chain rule, partial derivatives). Derivations are shown in full.
# - Most notebooks run on CPU. [Notebook 06](06-cnn.ipynb) (CNNs) includes ResNet fine-tuning on a real image dataset — a GPU (e.g. T4) is strongly recommended for that section.
#
# ## How to Read This Series
#
# **If you're new to deep learning:** Work through 01 → 05 in order — they build directly on each other. On a first pass through 05, focus on the results rather than every experiment; the code is extensive.
#
# **If you want the full picture:** Continue with 06 → 07 → 08 → 09 to go from CNNs through language models, RNNs, and Transformers. The appendices are nice to have if you're curious about CNN architectures and ResNets in depth (12) or want more theory on how neural networks learn (11).
#
# **If you want applied practice:** After 09, work through the Advanced Topics notebooks (13–17) to see the foundations applied to translation, generative models, diffusion, segmentation, and captioning.
#
# **Next steps:** After the core notebooks, continue with [Language Models from Scratch](../llm/index.ipynb).
