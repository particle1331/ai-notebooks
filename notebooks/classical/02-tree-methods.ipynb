# %% [markdown]
# # Tree-Based Methods

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# TODO: prose. Recursive binary splitting, Gini impurity vs. information gain, pruning. Decision trees as piecewise-constant models.

# %% [markdown]
# ## Random Forests

# %% [markdown]
# TODO: prose. Bagging reduces variance without increasing bias. Random feature subsampling decorrelates trees. Out-of-bag error as a free validation estimate.

# %% [markdown]
# ## Gradient Boosting: XGBoost and LightGBM

# %% [markdown]
# TODO: prose. Boosting fits residuals sequentially. Gradient boosting as gradient descent in function space. XGBoost: second-order Taylor expansion of the loss, regularized leaf scores. LightGBM: histogram-based splits, leaf-wise growth. Key hyperparameters: `n_estimators`, `learning_rate`, `max_depth`, `subsample`, `colsample_bytree`.

# %%
#| label: fig-decision-boundary
#| fig-cap: "Decision boundaries learned by a single decision tree, random forest, and XGBoost on a synthetic 2D classification dataset. Boosting produces smoother, more accurate boundaries."
#| code-fold: true

# TODO: Reproduce decision boundary comparison
# - Generate make_moons or make_classification (2 features) from sklearn
# - Fit: DecisionTreeClassifier, RandomForestClassifier, XGBClassifier
# - Three-panel plot: one decision boundary mesh per model
# - Overlay training points colored by class
# - Title each panel with model name + test accuracy

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# TODO: prose. Impurity-based importance (fast, biased toward high-cardinality features). Permutation importance (slower, model-agnostic, more reliable). Mean decrease in accuracy. Partial dependence plots.

# %% [markdown]
# ## SHAP

# %% [markdown]
# TODO: prose. Shapley values: game-theoretic attribution satisfying efficiency, symmetry, dummy, linearity axioms. TreeSHAP: exact polynomial-time computation for tree models. Global vs. local explanations.

# %%
#| label: fig-shap-summary
#| fig-cap: "SHAP beeswarm summary plot for an XGBoost model. Each row is a feature; each dot is a sample colored by feature value. The x-axis shows the SHAP value (impact on model output)."
#| code-fold: true

# TODO: Reproduce SHAP beeswarm plot
# - Dataset: California housing or diabetes (sklearn)
# - Fit XGBRegressor or XGBClassifier
# - Compute shap.TreeExplainer(model).shap_values(X)
# - shap.summary_plot(shap_values, X, plot_type='dot')
# - Top 10 features by mean |SHAP|
