# %% [markdown]
# # Feature Engineering & Unsupervised Learning

# %% [markdown]
# ## Encoding Categorical Features

# %% [markdown]
# TODO: prose. Ordinal encoding (preserves order, wrong for nominal). One-hot encoding (sparse, high-cardinality problem). Target encoding (mean of target per category -- leakage risk without proper CV). Hash encoding. Embeddings (NB06). When to use what.

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# TODO: prose. Filter methods (correlation, mutual information -- fast, model-agnostic). Wrapper methods (recursive feature elimination -- expensive). Embedded methods (L1 regularization, tree feature importances). The curse of dimensionality and why selection matters.

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# TODO: prose. SVD decomposition of the data matrix. Principal components as directions of maximum variance. Explained variance ratio. When PCA helps (linear correlations, high-dim dense features) and when it doesn't (tree models, sparse data).

# %%
#| label: fig-pca-variance
#| fig-cap: "Scree plot of explained variance ratio (bar) and cumulative explained variance (line) for the principal components of a high-dimensional dataset. The elbow indicates the effective intrinsic dimensionality."
#| code-fold: true

# TODO: Reproduce PCA scree plot
# - Dataset: digits, wine, or breast_cancer from sklearn
# - Fit PCA, plot explained_variance_ratio_ as bar chart
# - Overlay cumulative explained variance as line (secondary y-axis or same axis)
# - Mark 90% and 95% cumulative variance thresholds with dashed horizontals
# - X-axis: component index, Y-axis: explained variance ratio

# %% [markdown]
# ## Clustering: K-Means and HDBSCAN

# %% [markdown]
# TODO: prose. K-Means: Lloyd's algorithm, Voronoi partitions, elbow method for $k$. Limitations: assumes convex clusters, sensitive to initialization (k-means++). HDBSCAN: density-based, handles arbitrary shapes, discovers $k$ automatically, labels noise. Choosing between them.

# %%
#| label: fig-cluster-comparison
#| fig-cap: "K-Means vs. HDBSCAN on non-convex synthetic datasets. K-Means fails on moons and circles (wrong assumptions); HDBSCAN recovers the true structure and correctly labels outliers as noise."
#| code-fold: true

# TODO: Reproduce clustering comparison
# - Three datasets: make_moons, make_circles, make_blobs with varying density
# - Two rows (K-Means, HDBSCAN) x three columns (datasets)
# - Color points by assigned cluster label; noise points (HDBSCAN label=-1) in grey
# - Title each panel with method + adjusted Rand index vs. true labels

# %% [markdown]
# ## Anomaly Detection

# %% [markdown]
# TODO: prose. Isolation Forest: random splits isolate anomalies in fewer steps. Local Outlier Factor: density ratio between a point and its neighbors. One-class SVM. Reconstruction error (autoencoders -- covered in [Deep Learning Foundations NB14](/notebooks/deep/advanced/14-generative-models.html)). Choosing a threshold: precision-recall tradeoff, business cost asymmetry.
