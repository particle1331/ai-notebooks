# %% [markdown]
# # Evaluation & Causal Reasoning

# %% [markdown]
# ## Classification Metrics: Precision, Recall, and ROC

# %% [markdown]
# TODO: prose. Confusion matrix. Precision and recall: the tradeoff. F1 score and $F_\beta$ for asymmetric costs. ROC curve: TPR vs. FPR at varying thresholds. AUC-ROC as rank discrimination. Precision-recall curve: better for class imbalance. When to use ROC vs. PR.

# %%
#| label: fig-roc-curves
#| fig-cap: "ROC curves for logistic regression, random forest, and XGBoost on a binary classification benchmark. AUC is shown in the legend. The diagonal dashed line represents random guessing."
#| code-fold: true

# TODO: Reproduce ROC curve comparison
# - Dataset: breast_cancer from sklearn (binary, realistic class balance)
# - Fit LogisticRegression, RandomForestClassifier, XGBClassifier
# - Plot ROC curve for each model on the same axes
# - Label each curve with model name + AUC in legend
# - Dashed diagonal (random classifier baseline)
# - Also show Precision-Recall curves in a second panel

# %% [markdown]
# ## Calibration

# %% [markdown]
# TODO: prose. A model is calibrated if predicted probability $\hat{p}$ matches observed frequency. Reliability diagram (calibration plot). Expected Calibration Error (ECE). Why tree ensembles and SVMs are poorly calibrated. Platt scaling and isotonic regression as post-hoc calibration. When calibration matters: ranking vs. decision-making.

# %%
#| label: fig-calibration-plot
#| fig-cap: "Reliability diagrams (calibration curves) for logistic regression, random forest, and XGBoost before and after Platt scaling. A perfectly calibrated model follows the diagonal."
#| code-fold: true

# TODO: Reproduce calibration curves
# - Same dataset and models as ROC figure
# - Use sklearn.calibration.calibration_curve
# - Plot uncalibrated vs. calibrated (CalibratedClassifierCV with method='sigmoid')
# - One panel per model, or overlay all on one axes
# - Report ECE in annotation

# %% [markdown]
# ## Bootstrap Confidence Intervals

# %% [markdown]
# TODO: prose. The bootstrap: resample with replacement $B$ times, compute statistic on each resample, take the empirical distribution. Percentile interval vs. BCa (bias-corrected and accelerated) interval. When to use bootstrap over asymptotic approximations. Application: confidence interval on AUC, on a metric difference between models.

# %% [markdown]
# ## A/B Testing

# %% [markdown]
# TODO: prose. Two-sample $z$-test and $t$-test. Power analysis and sample size calculation. Multiple testing: Bonferroni, FDR (Benjamini-Hochberg). Common pitfalls: peeking, survivorship bias, novelty effect. Sequential testing (always-valid $p$-values) for online experiments.

# %% [markdown]
# ## Causal Inference: Propensity Scores and ATE

# %% [markdown]
# TODO: prose. Correlation vs. causation. Potential outcomes framework (Rubin): $Y_i(1)$, $Y_i(0)$, the fundamental problem of causal inference. Average Treatment Effect (ATE) and Average Treatment Effect on the Treated (ATT). Confounders and selection bias. Propensity score matching: estimate $P(T=1 \mid X)$, match treated and control units. Inverse probability weighting (IPW). When randomization is impossible: observational studies, instrumental variables (brief).
