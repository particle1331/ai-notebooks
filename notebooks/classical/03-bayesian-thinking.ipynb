# %% [markdown]
# # Bayesian Thinking

# %% [markdown]
# ## Probabilistic Reasoning and Bayes' Rule

# %% [markdown]
# TODO: prose. Prior, likelihood, posterior. The Bayesian update as a principled way to incorporate evidence. Conjugate priors (Beta-Binomial, Dirichlet-Multinomial, Normal-Normal). Posterior predictive distribution.

# %%
#| label: fig-prior-posterior
#| fig-cap: "Sequential Bayesian updating with the Beta-Binomial model. Each panel shows the prior (dashed) and posterior (solid) after observing $n$ coin flips. The posterior concentrates around the true probability as data accumulates."
#| code-fold: true

# TODO: Reproduce prior-to-posterior update visualization
# - Model: Beta(alpha, beta) prior on coin bias p
# - Simulate coin flips from a true p=0.7
# - Four panels: posterior after 0, 5, 20, 100 observations
# - Each panel: plot Beta PDF, mark true p with dashed vertical
# - Show alpha, beta updating rule in annotation

# %% [markdown]
# ## Naive Bayes Classifiers

# %% [markdown]
# TODO: prose. Conditional independence assumption. Gaussian NB for continuous features, Multinomial NB for text. Log-probability for numerical stability. Despite the strong independence assumption, Naive Bayes often works well in practice -- why.

# %% [markdown]
# ## Priors as Regularization

# %% [markdown]
# TODO: prose. MAP estimation with a Gaussian prior = L2 regularization (Ridge). MAP with a Laplace prior = L1 regularization (Lasso). The Bayesian interpretation unifies regularization with uncertainty quantification. Full Bayesian inference vs. MAP: when the difference matters.

# %% [markdown]
# ## Bayesian Optimization

# %% [markdown]
# TODO: prose. Surrogate model (Gaussian Process) over the objective function. Acquisition function (Expected Improvement, UCB) trades off exploration and exploitation. Efficient for expensive black-box objectives like hyperparameter tuning.

# %%
#| label: fig-bayesian-optimization
#| fig-cap: "Bayesian optimization after five evaluations of a noisy 1D objective. The GP surrogate (mean ± 2 std) is shown in blue; the acquisition function (Expected Improvement) is shown below. The next query point is where EI is maximized."
#| code-fold: true

# TODO: Reproduce Bayesian optimization visualization
# - True objective: noisy sinusoidal function on [0, 1]
# - Fit GP (sklearn.gaussian_process.GaussianProcessRegressor) to 5 observations
# - Two-panel stacked plot:
#   Top: GP mean, ±2 std shading, observed points, true function
#   Bottom: Expected Improvement acquisition function, mark next query
# - Use RBF kernel with noise

# %% [markdown]
# ## Hyperparameter Tuning with Optuna

# %% [markdown]
# TODO: prose. Optuna's TPE (Tree-structured Parzen Estimator) as a practical alternative to GP-based BO. `study.optimize()` loop. Pruning unpromising trials mid-training with `optuna.TrialPruned`. Visualization: parallel coordinate plot, parameter importances.
