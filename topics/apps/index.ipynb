# %% [markdown]
# # App Development

# %% [markdown]
# 🦄 Is it finally happening?

# %% [markdown]
# - frontend (reflex)
# - backend (rest api)
# - system design for large scale data apps (celery, rabbitmq, etc)
# - projects & demos
