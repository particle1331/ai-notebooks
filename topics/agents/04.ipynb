# %% [markdown]
# # Pattern 3: Planning (ReAct)

# %% [markdown]
# act (tool) -> observation -> thought
#
# either output of act again.
#
# planning = deciding what sequence of steps to follows ccomplish a large task
